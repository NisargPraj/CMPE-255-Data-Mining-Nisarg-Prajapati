# %%
# !pip install transformers

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "mlfoundations/tabula-8b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
model.to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# config.json:   0%|          | 0.00/697 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00007.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/2.57G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128258, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
# ...

# %%
input_text = "Explain the importance of data preprocessing in machine learning."
input_data = tokenizer(input_text, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# %%
with torch.no_grad():
    output = model.generate(**input_data, max_new_tokens=10, temperature=0.7, do_sample=True)
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print("Generated Text:", generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generated Text: Explain the importance of data preprocessing in machine learning. Explain the steps involved in data preprocessing.
# Machine learning
